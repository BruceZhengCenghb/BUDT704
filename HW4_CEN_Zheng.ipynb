# %% [markdown]
# Name: <Zheng CEN>
# Course: BUDT704
# Section: <0502>
# Date: <10/22/21>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from numpy import nan as NA
from pylab import *

# %% [markdown]
# #1.Consider the data within the Excel spreadsheet:
# a. (2 points) Load the data from the file into a data frame with rank denoted as the index. Hint:
# Review the Pandas documentation to see how you can load data from an Excel spreadsheet.
# b. (2 points) Print the total number of companies on the list
# c. (4 points) Print a data frame containing companies ranked within the top 25, including all data
# known about them.

# %%
df_inc = pd.read_excel('HW5_Socially Responsible ETFs.xlsx', index_col= 'RANK')
df_inc.head(4)
# Out:
#                                               URL     CITY      GROWTH  \
# RANK
# 1            https://www.inc.com/profile/swanleap  Madison  75660.8425
# 2          https://www.inc.com/profile/popsockets  Boulder  71423.7620
# 3           https://www.inc.com/profile/home-chef  Chicago  60165.5058
# 4     https://www.inc.com/profile/velocity-global   Denver  39816.5093
#
#       EMPLOYEES     COMPANY NAME                    WEBSITE     CITY.1 STATE  \
# RANK
# 1            49         SwanLeap        http://swanleap.com  Wisconsin    WI
# 2           118       PopSockets      http://popsockets.com   Colorado    CO
# 3           865        Home Chef               homechef.com   Illinois    IL
# 4            55  Velocity Global  http://velocityglobal.com   Colorado    CO
#
#         REVENUW  ZIP CODE  FOUNDED                      INDUSTRY  \
# RANK
# 1      98965631     53719   2013.0    Logistics & Transportation
# 2     168837562     80301   2010.0  Consumer Products & Services
# ...

# %%
total_cpny = df_inc['COMPANY NAME'].value_counts
print(total_cpny)
# Out:
# <bound method IndexOpsMixin.value_counts of RANK
# 1                                SwanLeap
# 2                              PopSockets
# 3                               Home Chef
# 4                         Velocity Global
# 5                            DEPCOM Power
#                       ...
# 4996                        Pentec Health
# 4997                  Progressive Freight
# 4998    Traffic Planning and Design, Inc.
# 4999                 Weld Power Generator
# 5000                Pedigree Technologies
# Name: COMPANY NAME, Length: 5000, dtype: object>

# %%
print("how many companies:", df_inc['COMPANY NAME'].count(),"\n")
# Out:
# how many companies: 5000

# %% [markdown]
# 1c)

# %%
df_1c = df_inc[:25]
print('', df_1c)
# Out:
#                                                      URL           CITY  \
# RANK
# 1                  https://www.inc.com/profile/swanleap        Madison
# 2                https://www.inc.com/profile/popsockets        Boulder
# 3                 https://www.inc.com/profile/home-chef        Chicago
# 4           https://www.inc.com/profile/velocity-global         Denver
# 5              https://www.inc.com/profile/depcom-power     Scottsdale
# 6           https://www.inc.com/profile/aeronux-airways       Marietta
# 7            https://www.inc.com/profile/diamond-assets         Milton
# 8      https://www.inc.com/profile/gforce-life-sciences        Chicago
# 8                  https://www.inc.com/profile/flexport  San Francisco
# 9              https://www.inc.com/profile/scientistcom   Solana Beach
# 10    https://www.inc.com/profile/the-garrett-companies      Greenwood
# 11        https://www.inc.com/profile/dgc-international         Vienna
# ...

# %% [markdown]
# #2 Upon import of the data and the columns, you notice the data frame is not completely clean
# and could benefit from some modifications. Describe and complete two different modifications to
# achieve tidy data.

# %%
# correct the col name
df_inc.rename(columns={'REVENUW':'REVENUE'}, inplace = True)
df_inc.rename(columns={'STATE':'State Code'}, inplace = True)
df_inc.rename(columns={'CITY.1':'STATE'}, inplace = True)
df_inc.head()
# Out:
#                                               URL        CITY      GROWTH  \
# RANK
# 1            https://www.inc.com/profile/swanleap     Madison  75660.8425
# 2          https://www.inc.com/profile/popsockets     Boulder  71423.7620
# 3           https://www.inc.com/profile/home-chef     Chicago  60165.5058
# 4     https://www.inc.com/profile/velocity-global      Denver  39816.5093
# 5        https://www.inc.com/profile/depcom-power  Scottsdale  38962.9022
#
#       EMPLOYEES     COMPANY NAME                    WEBSITE      STATE  \
# RANK
# 1            49         SwanLeap        http://swanleap.com  Wisconsin
# 2           118       PopSockets      http://popsockets.com   Colorado
# 3           865        Home Chef               homechef.com   Illinois
# 4            55  Velocity Global  http://velocityglobal.com   Colorado
# 5           104     DEPCOM Power            depcompower.com    Arizona
#
#      State Code    REVENUE  ZIP CODE  FOUNDED                      INDUSTRY  \
# ...

# %%
## check the Nan remain 
#print("which has Nan?\n", df_inc.isnull(),"\n")
print("each column has NaN\n", df_inc.isnull().sum(),"\n")
print("total has NaN\n", df_inc.isnull().sum().sum(),"\n")
print("each column values\n", df_inc.count(),"\n")
#print("which column values\n", df_inc.notnull(),"\n")
# Out:
# each column has NaN
#  URL                0
# CITY               1
# GROWTH             0
# EMPLOYEES          0
# COMPANY NAME       0
# WEBSITE            0
# STATE              1
# State Code         1
# REVENUE            0
# ZIP CODE           0
# FOUNDED            1
# INDUSTRY           0
# CITY, STATE       24
# Unnamed: 14     4998
# Unnamed: 15     4998
# dtype: int64
#
# total has NaN
#  10024
#
# each column values
#  URL             5000
# CITY            4999
# GROWTH          5000
# EMPLOYEES       5000
# COMPANY NAME    5000
# WEBSITE         5000
# STATE           4999
# State Code      4999
# REVENUE         5000
# ZIP CODE        5000
# FOUNDED         4999
# INDUSTRY        5000
# CITY, STATE     4976
# Unnamed: 14        2
# Unnamed: 15        2
# dtype: int64

# %%
# delete all NAN col 
df_inc.drop(['Unnamed: 14', 'Unnamed: 15'],axis=1, inplace= True)
df_inc.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-c88ed4ee3b7f> in <module>
#       1 # delete all NAN col
# ----> 2 df_inc.drop(['Unnamed: 14', 'Unnamed: 15'],axis=1, inplace= True)
#       3 df_inc.head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
# ...

# %%
# delete the rows contain NA in the current dataframe
df_inc.dropna(inplace = True)

# %%
# check the Nan remain again
#print("which has Nan?\n", df_inc.isnull(),"\n")
print("each column has NaN\n", df_inc.isnull().sum(),"\n")
print("total has NaN\n", df_inc.isnull().sum().sum(),"\n")
print("each column values\n", df_inc.count(),"\n")
#print("which column values\n", df_inc.notnull(),"\n")
# Out:
# each column has NaN
#  URL             0
# CITY            0
# GROWTH          0
# EMPLOYEES       0
# COMPANY NAME    0
# WEBSITE         0
# STATE           0
# State Code      0
# REVENUE         0
# ZIP CODE        0
# FOUNDED         0
# INDUSTRY        0
# CITY, STATE     0
# dtype: int64
#
# total has NaN
#  0
#
# each column values
#  URL             4973
# CITY            4973
# GROWTH          4973
# EMPLOYEES       4973
# COMPANY NAME    4973
# WEBSITE         4973
# STATE           4973
# State Code      4973
# REVENUE         4973
# ZIP CODE        4973
# FOUNDED         4973
# INDUSTRY        4973
# CITY, STATE     4973
# dtype: int64

# %% [markdown]
# #3a)

# %%
df_states = pd.read_csv('HW4_states_by_region.csv')
df_states.head()
# Out:
#         State State Code Region            Division
# 0      Alaska         AK   West             Pacific
# 1     Alabama         AL  South  East South Central
# 2    Arkansas         AR  South  West South Central
# 3     Arizona         AZ   West            Mountain
# 4  California         CA   West             Pacific

# %%
df_states = df_states[['State Code', 'Region']]
df_states.head()
# Out:
#   State Code Region
# 0         AK   West
# 1         AL  South
# 2         AR  South
# 3         AZ   West
# 4         CA   West

# %%
pd.merge(df_inc, df_states[['State Code', 'Region']], left_on='State Code', right_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-a48a76d0bfd2> in <module>
# ----> 1 pd.merge(df_inc, df_states[['State Code', 'Region']], left_on='State Code', right_index=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     670         # validate the merge keys dtypes. We may need to coerce
#     671         # to avoid incompatible dtypes
# ...

# %% [markdown]
# #4

# %%
mean_df = df_inc['REVENUE'].mean()
print(f'the mean of revenues of all companies is {mean_df}')
# Out:
# the mean of revenues of all companies is 41221263.2006

# %%
max_df = df_inc['REVENUE'].max()
print(f'the max of revenues of all companies is {max_df}')
# Out:
# the max of revenues of all companies is 16433210000

# %%
min_df = df_inc['REVENUE'].min()
print(f'the min of revenues of all companies is {min_df}')
# Out:
# the min of revenues of all companies is 1952209

# %%
std_df = df_inc['REVENUE'].std()
print(f'the standard deviasion of revenues of all companies is {std_df}')
# Out:
# the standard deviasion of revenues of all companies is 282990264.70188546

# %%
# change time to numeric and the comparision
df_inc['FOUNDED'] = pd.to_numeric(df_inc['FOUNDED'])
df_2015 = df_inc[df_inc['FOUNDED'] <= 2015]
df_2015.head()
# Out:
#                                                     URL         CITY  \
# RANK
# 1                  https://www.inc.com/profile/swanleap      Madison
# 2                https://www.inc.com/profile/popsockets      Boulder
# 3                 https://www.inc.com/profile/home-chef      Chicago
# 4           https://www.inc.com/profile/velocity-global       Denver
# 5              https://www.inc.com/profile/depcom-power   Scottsdale
# ...                                                 ...          ...
# 4996          https://www.inc.com/profile/pentec-health   Glen Mills
# 4997    https://www.inc.com/profile/progressive-freight  Thomasville
# 4998  https://www.inc.com/profile/traffic-planning-a...    Pottstown
# 4999   https://www.inc.com/profile/weld-power-generator     Millbury
# 5000  https://www.inc.com/profile/pedigree-technologies        Fargo
#
#           GROWTH  EMPLOYEES                       COMPANY NAME  \
# RANK
# ...

# %%
# number of company 
num_com_2015 = df_2015.shape[0]
df_2015_rev = df_2015[df_2015['REVENUE'] >= 50000000]
num_com_2015_rev = df_2015_rev.shape[0]

# %%
print(f'number of company before 2015 is :{num_com_2015}')
print(f'number of company before 2015 with revenue > 50m is :{num_com_2015_rev}')
print('percentage of company before 2015 with revenue > 50m is', num_com_2015_rev / num_com_2015 *100,'%')
# Out:
# number of company before 2015 is :4999
# number of company before 2015 with revenue > 50m is :681
# percentage of company before 2015 with revenue > 50m is 13.622724544908982 %

# %% [markdown]
# 4c)
# upon all we found, there are more than 13% companies earn a profit more than 50m, compare to 40m average of all the company. But compare with highest companies, this is not enough. The reason may because of depreciation of dollars. So compare the data of different years may exist some error.

# %% [markdown]
# #5 Write a Python function with parameters of data frame, category, value, and a number that
# specifies the number of rows to display in the result. The category and value should have default
# values of 'None' and the number of rows (n) should have a default value of 10. n will specify the
# number of rows to display in the result. The function should return a data frame containing the top n
# rows of companies, based on revenues for a specific value in the category, only if both category and
# value are provided. If both category and value are not provided, the top n companies overall should be
# displayed.

# %%
def find_top(df, cate, val, n=10):   # cate category.  val. value
    if (cate != None)&(val != None):
        df= df[df[cate]== val]
        df= df.sort_values(by = 'REVENUE', ascending = False)
        return df[:n]
    else:  # the condition that any one of category and value is none
        df = df.sort_values(by = 'REVENUE', ascending = False)
        df = df[:n]
        return df

# %% [markdown]
# #6 Using the previously created function, create data frames for each of the following:
# a. (2 points) The top fifteen overall companies
# b. (2 points) The top ten companies in the food and beverage industry
# c. (2 points) The top three companies located in New York City
# d. (2 points) The top five companies in Maryland

# %%
df_6a = find_top(df_inc,None,None,15)
df_6b = find_top(df_inc, 'INDUSTRY','Food & Beverage',10)
df_6c = find_top(df_inc, 'CITY','New York City',3)
df_6d = find_top(df_inc, 'STATE','Maryland',5)

# %%
df_6a
# Out:
#                                                     URL           CITY  \
# RANK
# 1288     https://www.inc.com/profile/prime-therapeutics          Eagan
# 1318       https://www.inc.com/profile/allied-universal      Santa Ana
# 4226   https://www.inc.com/profile/carahsoft-technology         Reston
# 3439               https://www.inc.com/profile/endeavor  Beverly Hills
# 4341              https://www.inc.com/profile/drivetime          Tempe
# 4204                 https://www.inc.com/profile/armada     Pittsburgh
# 3546       https://www.inc.com/profile/srs-distribution       McKinney
# 2064         https://www.inc.com/profile/pinnacle-group         Dallas
# 4973         https://www.inc.com/profile/insight-global        Atlanta
# 3010  https://www.inc.com/profile/transportation-ins...        Hickory
# 1388                 https://www.inc.com/profile/victra        Raleigh
# 3496                 https://www.inc.com/profile/strike  The Woodlands
# ...

# %%
df_6b
# Out:
#                                                     URL         CITY  \
# RANK
# 3757      https://www.inc.com/profile/jersey-mikes-subs    Manasquan
# 3483         https://www.inc.com/profile/monogram-foods      Memphis
# 998         https://www.inc.com/profile/gps-hospitality      Atlanta
# 3434  https://www.inc.com/profile/freddys-frozen-cus...      Wichita
# 4061      https://www.inc.com/profile/blount-fine-foods   Fall River
# 3                 https://www.inc.com/profile/home-chef      Chicago
# 3537  https://www.inc.com/profile/coopers-hawk-winer...  Countryside
# 2436    https://www.inc.com/profile/nothing-bundt-cakes      Addison
# 515               https://www.inc.com/profile/mod-pizza     Bellevue
# 4633     https://www.inc.com/profile/studio-movie-grill       Dallas
#
#           GROWTH  EMPLOYEES                            COMPANY NAME  \
# RANK
# 3757     97.4898      19000                      Jersey Mike's Subs
# ...

# %%
df_6c
# Out:
#                                                     URL           CITY  \
# RANK
# 4855  https://www.inc.com/profile/sterling-talent-so...  New York City
# 71                  https://www.inc.com/profile/compass  New York City
# 97                  https://www.inc.com/profile/peloton  New York City
#
#          GROWTH  EMPLOYEES               COMPANY NAME  \
# RANK
# 4855    61.7196       4087  Sterling Talent Solutions
# 71    4309.0950        464                    Compass
# 97    3710.7823        872                    Peloton
#
#                           WEBSITE     STATE State Code    REVENUE  ZIP CODE  \
# RANK
# 4855  sterlingtalentsolutions.com  New York         NY  480956135     10004
# 71                    compass.com  New York         NY  370560142     10011
# 97                 onepeloton.com  New York         NY  328337000     10001
#
#       FOUNDED                      INDUSTRY  \
# RANK
# 4855   1975.0  Business Products & Services
# ...

# %%
df_6d
# Out:
#                                                     URL          CITY  \
# RANK
# 3357            https://www.inc.com/profile/infiniti-hr  Burtonsville
# 349         https://www.inc.com/profile/t-rex-solutions     Greenbelt
# 3196  https://www.inc.com/profile/the-maryland-and-d...     Salisbury
# 1732                https://www.inc.com/profile/n2grate     Greenbelt
# 2077  https://www.inc.com/profile/tista-science-and-...     Rockville
#
#          GROWTH  EMPLOYEES                                       COMPANY NAME  \
# RANK
# 3357   115.2400      34499                                        INFINITI HR
# 349   1427.5775        385                                    T-Rex Solutions
# 3196   122.8835         30  The Maryland and Delaware Group of Long and Fo...
# 1732   263.3315         44                                            n2grate
# 2077   214.2944        296                       TISTA Science and Technology
#
# ...

# %% [markdown]
# #7Awards will be given to companies in service industries based on their revenue. This
# includes any company who is in an industry with a "Services" name included as part of its industry. The
# top quarter of these companies will be given a Trailblazer award, while companies who didn't make the
# top quarter, but made the top half will be given a Pioneer award. For each company earning an award,
# provide a data frame showing the company, its rank, its revenue, and which award it will earn, sorted
# by revenue in descending order.

# %%
#including service str
df_ser = df_inc[df_inc['INDUSTRY'].str.contains('Services')]
df_ser2 = df_ser.sort_values(by = 'REVENUE', ascending = False)
#df_ser.head()
df_ser2.head()
# Out:
#                                                    URL       CITY    GROWTH  \
# RANK
# 4226  https://www.inc.com/profile/carahsoft-technology     Reston   80.4559
# 4341             https://www.inc.com/profile/drivetime      Tempe   76.6689
# 3546      https://www.inc.com/profile/srs-distribution   McKinney  106.2021
# 4973        https://www.inc.com/profile/insight-global    Atlanta   58.1746
# 2110       https://www.inc.com/profile/jeunesse-global  Lake Mary  210.2303
#
#       EMPLOYEES          COMPANY NAME              WEBSITE     STATE  \
# RANK
# 4226        900  Carahsoft Technology        carahsoft.com  Virginia
# 4341       6111             DriveTime        drivetime.com   Arizona
# 3546       3132      SRS Distribution  srsdistribution.com     Texas
# 4973       2570        Insight Global    insightglobal.com   Georgia
# 2110        825       Jeunesse Global   jeunesseglobal.com   Florida
#
#      State Code     REVENUE  ZIP CODE  FOUNDED                      INDUSTRY  \
# ...

# %% [markdown]
# #8

# %%
plt.figure(figsize=(6,6))
size = df_inc[['STATE']]
plt.pie(size,autopct='%.1f%%')
plt.title('STATE of company')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-163-6b81f42b2c90> in <module>
# ----> 1 plt.figure(figsize=(6,6))
#       2 size = df_inc[['STATE']]
#       3 #label=
#       4 plt.pie(size,autopct='%.1f%%')
#       5 plt.title('STATE of company')
#
# AttributeError: module 'matplotlib' has no attribute 'figure'

# %% [markdown]
# use the state here to make up the pie chart. the figure shows the proportion of companies located in different states. The activity can be viewed.

# %% [markdown]
# "I pledge on my honor that I have not given nor received any unauthorized
# assistance on this assignment."
# --ZhengCEN
